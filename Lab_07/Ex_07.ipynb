# %% [markdown]
# <a href="https://colab.research.google.com/github/andresvidal27/MLF_Labs_Andr-s_Vidal_Mira/blob/main/Lab_07/Ex_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # MKA-MLF, Lab_07 Convolutional Neural Networks

# %% [markdown]
# ## Exercise - XOR Gate

# %% [markdown]
# ## Exercise - Hand-written digits recognition

# %% [markdown]
# Create CNN which will process and recognize handwritten digits. For this purposes please use the MNIST database (Modified National Institute of Standards and Technology database) which is a large database of handwritten digits that is commonly used for training various image processing systems.
#
# The datasample of the MNIST datasets can be see in the following picture

# %% [markdown]
# ### Task description

# %% [markdown]
# In the terms of machine learning, the Hand-written digits recognition can be threated as a multi-class classification problem. This is very important knowledge to structure our model in the correct way (Especially the output-layer, including the number of neurons and activations function and the overall loss function and classification metrics)

# %% [markdown]
# ### 0. Import libraries

# %% [markdown]
# Import the all necessary libraries, you can get inspired by the previous exercises. You can improst the libraries gradually, when do you progressing with the task

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.datasets import mnist
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
###################################
# Write your own code here #
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.utils import to_categorical
###################################
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### 1.1 Load Dataset

# %% [markdown]
# You can load the dataset using the following code

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# #### 1.2 Dataset examination

# %% [markdown]
# Using the following code, display random images,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels = y_data[selected_ind]
  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img, cmap="gray")

  for id_label, label in enumerate(selected_labels):
    plt.text(14 + 28*id_label, 28*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %% [markdown]
# Examine the dataset. Answer for yourself the following questions:
#
# - What kind of data occurs in our dataset?
# - How many data samples do we have in train and test datasets?
# - How many colour channels does the input variable have?
# - What is the size of the input images?
# - What is the necessary preprocessing of the input data X?
# - How many classes do we have in target varoable?
# - What is the necessary preprocessing of target variable y?

# %% [markdown]
# #### 1.3 Dataset preprocessing

# %% [markdown]
# Perform the necessary data preprocessing. The best way to preprocess the data would be one hot encoding for the target variable and normalization for the input variable (using min-max or z-score normalization)

# %%
###################################
# Write your own code here #
# Normalización Min-Max (0 a 1) y redimensionamiento para la CNN
X_train = X_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# One-hot encoding para la variable objetivo
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
###################################

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# In this section, your task will be to define the model architecture. The intial structure can be defined as follows:
#
# Input_layer -> Convolutional_layer(kernel_size=(3,3), no_channels=32) -> Maxpooling_layer(kernel_size=(2, 2)) -> Flatten_layer -> Dense_layer (num_classes)

# %% [markdown]
# #### 2.1 Define the model structure

# %%
model = Sequential([
    Input(shape=(28, 28, 1)), # Explicitly define the Input layer
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(10, activation='softmax')
])

# %% [markdown]
# #### 2.2 Compile the model

# %% [markdown]
# Build the model, use the relevant metrics, optimizer and loss function. While choosing the metrics and loss function, consider fact that we are are trying to solve the multiclass classification problem

# %%
loss = 'categorical_crossentropy'
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
metrics = ['accuracy']
###################################
# Write your own code here #
model.compile(loss=loss,
              optimizer=optimizer,
              metrics=metrics)
###################################
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 5408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │        54,090 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,410 (212.54 KB)
#  Trainable params: 54,410 (212.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %% [markdown]
# train your model, define the relevant hyperparameters (no. epochs, batch_size), use 20p of the training data for validation

# %%
###################################
# Write your own code here #
epochs = 10
batch_size = 128

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.2)
###################################
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8898 - loss: 0.4019 - val_accuracy: 0.9484 - val_loss: 0.1900
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9575 - loss: 0.1504 - val_accuracy: 0.9701 - val_loss: 0.1124
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9724 - loss: 0.1001 - val_accuracy: 0.9764 - val_loss: 0.0909
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.9781 - loss: 0.0791 - val_accuracy: 0.9776 - val_loss: 0.0801
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.9811 - loss: 0.0675 - val_accuracy: 0.9778 - val_loss: 0.0733
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - accuracy: 0.9826 - loss: 0.0590 - val_accuracy: 0.9804 - val_loss: 0.0673
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 45ms/step - accuracy: 0.9844 - loss: 0.0536 - val_accuracy: 0.9797 - val_loss: 0.0693
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9861 - loss: 0.0482 - val_accuracy: 0.9812 - val_loss: 0.0660
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.9870 - loss: 0.0443 - val_accuracy: 0.9799 - val_loss: 0.0681
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 44ms/step - accuracy: 0.9881 - loss: 0.0401 - val_accuracy: 0.9812 - val_loss: 0.0645

# %% [markdown]
# #### 3.1 Model Evaluation on validation data

# %% [markdown]
# Plot the development of the training and validation loss, and training and validation metrics.

# %%
###################################
# Write your own code here #
plt.figure(figsize=(12, 5))

# Gráfica de la función de pérdida (Loss)
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Gráfica de la precisión (Accuracy)
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
###################################

# %% [markdown]
# ### 4. Model evaluation

# %% [markdown]
# Evaluate the model on the testing dataset using the relevant metrics. Use the confusion metrics as the one of the metrics.

# %%
###################################
# Write your own code here #
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 1. Evaluar las métricas generales en el dataset de prueba
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Métricas en Test -> Loss: {test_loss:.4f} | Accuracy: {test_acc:.4f}")

# 2. Preparar los datos para la matriz de confusión
# El modelo devuelve probabilidades, así que tomamos la clase con mayor probabilidad (argmax)
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# 3. Crear y dibujar la matriz de confusión
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))

plt.figure(figsize=(10, 8))
disp.plot(cmap='Blues', values_format='d', ax=plt.gca())
plt.title('Matriz de Confusión')
plt.show()
###################################
# Out:
# Métricas en Test -> Loss: 0.0575 | Accuracy: 0.9808
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %% [markdown]
# ### 5. Hyperparameter tunning and regularization techniques

# %% [markdown]
# When your code is ready and fully functional, try several changes in the hyperparameters and see how they influence the testing metrics. Try changes in the network structure. You can also try adding regularization techniques such as L1, L2, and Dropout. Based on the development of training and validation loss, try to identify overfitting and avoid it

# %%
###################################
# Write your own code here #
from keras.regularizers import l2

# Creamos un nuevo modelo intentando evitar el overfitting
model_tuned = Sequential([
    Input(shape=(28, 28, 1)), # Explicitly define the Input layer
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compilamos
model_tuned.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])

# Entrenamos el nuevo modelo
print("Entrenando el modelo con regularización y dropout...")
history_tuned = model_tuned.fit(X_train, y_train,
                                batch_size=128,
                                epochs=10,
                                validation_split=0.2,
                                verbose=1)
###################################
# Out:
# Entrenando el modelo con regularización y dropout...
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.8701 - loss: 0.5739 - val_accuracy: 0.9722 - val_loss: 0.2215
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 40s 105ms/step - accuracy: 0.9567 - loss: 0.2538 - val_accuracy: 0.9809 - val_loss: 0.1582
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 40s 104ms/step - accuracy: 0.9661 - loss: 0.1956 - val_accuracy: 0.9822 - val_loss: 0.1335
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 41s 103ms/step - accuracy: 0.9701 - loss: 0.1693 - val_accuracy: 0.9858 - val_loss: 0.1161
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.9717 - loss: 0.1598 - val_accuracy: 0.9863 - val_loss: 0.1133
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 39s 104ms/step - accuracy: 0.9748 - loss: 0.1499 - val_accuracy: 0.9862 - val_loss: 0.1097
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 39s 104ms/step - accuracy: 0.9752 - loss: 0.1463 - val_accuracy: 0.9879 - val_loss: 0.1038
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 41s 109ms/step - accuracy: 0.9766 - loss: 0.1423 - val_accuracy: 0.9866 - val_loss: 0.1064
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 39s 104ms/step - accuracy: 0.9767 - loss: 0.1393 - val_accuracy: 0.9874 - val_loss: 0.1082
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 40s 105ms/step - accuracy: 0.9778 - loss: 0.1366 - val_accuracy: 0.9896 - val_loss: 0.1033
